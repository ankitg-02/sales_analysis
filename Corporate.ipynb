# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitg-02/sales_analysis/blob/main/Corporate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing data from excelsheet
corporate_sales=pd.read_excel("/content/Sample-sales-data-excel.xls")
data=pd.DataFrame(corporate_sales)
data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
corporate_mod=data.groupby('Segment')
corporate_data=corporate_mod.get_group('Corporate')
corporate_data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 21        22  CA-2016-137330 2016-12-09 2016-12-13  Standard Class
# 22        23  CA-2016-137330 2016-12-09 2016-12-13  Standard Class
# 35        36  CA-2016-117590 2016-12-08 2016-12-10     First Class
# 36        37  CA-2016-117590 2016-12-08 2016-12-10     First Class
# ...      ...             ...        ...        ...             ...
# 9964    9965  CA-2016-146374 2016-12-05 2016-12-10    Second Class
# 9965    9966  CA-2016-146374 2016-12-05 2016-12-10    Second Class
# 9966    9967  CA-2016-146374 2016-12-05 2016-12-10    Second Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
#
#      Customer ID    Customer Name    Segment        Country         City  ...  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# 21      KB-16585        Ken Black  Corporate  United States      Fremont  ...
# 22      KB-16585        Ken Black  Corporate  United States      Fremont  ...
# 35      GH-14485        Gene Hale  Corporate  United States   Richardson  ...
# 36      GH-14485        Gene Hale  Corporate  United States   Richardson  ...
# ...          ...              ...        ...            ...          ...  ...
# 9964    HE-14800     Harold Engle  Corporate  United States       Newark  ...
# 9965    HE-14800     Harold Engle  Corporate  United States       Newark  ...
# 9966    HE-14800     Harold Engle  Corporate  United States       Newark  ...
# 9987    RA-19885     Ruben Ausman  Corporate  United States       Athens  ...
# 9988    RA-19885     Ruben Ausman  Corporate  United States       Athens  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 2          90036     West  OFF-LA-10000240  Office Supplies       Labels
# 21         68025  Central  OFF-AR-10000246  Office Supplies          Art
# 22         68025  Central  OFF-AP-10001492  Office Supplies   Appliances
# 35         75080  Central  TEC-PH-10004977       Technology       Phones
# 36         75080  Central  FUR-FU-10003664        Furniture  Furnishings
# ...          ...      ...              ...              ...          ...
# 9964       19711     East  FUR-FU-10002671        Furniture  Furnishings
# 9965       19711     East  OFF-PA-10000349  Office Supplies        Paper
# 9966       19711     East  OFF-EN-10004483  Office Supplies    Envelopes
# 9987       30605    South  TEC-AC-10001539       Technology  Accessories
# 9988       30605    South  TEC-PH-10004006       Technology       Phones
#
#                                            Product Name     Sales  Quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...    14.620         2
# 21                                           Newell 318    19.460         7
# 22          Acco Six-Outlet Power Strip, 4' Cord Length    60.340         7
# 35                                          GE 30524EE4  1097.544         7
# 36    Electrix Architect's Clamp-On Swing Arm Lamp, ...   190.920         5
# ...                                                 ...       ...       ...
# 9964  Electrix 20W Halogen Replacement Bulb for Zoom...    13.400         1
# 9965                                  Easy-staple paper     4.980         1
# 9966         #10 White Business Envelopes,4 1/8 x 9 1/2   109.690         7
# 9987  Logitech G430 Surround Sound Gaming Headset wi...    79.990         1
# 9988                    Panasonic KX - TS880B Telephone   206.100         5
#
#       Discount    Profit
# 2          0.0    6.8714
# 21         0.0    5.0596
# 22         0.0   15.6884
# 35         0.2  123.4737
# 36         0.6 -147.9630
# ...        ...       ...
# 9964       0.0    6.4320
# 9965       0.0    2.3406
# 9966       0.0   51.5543
# 9987       0.0   28.7964
# 9988       0.0   55.6470
#
# [3020 rows x 21 columns]

# %%
corporate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3020 entries, 2 to 9988
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         3020 non-null   int64
#  1   Order ID       3020 non-null   object
#  2   Order Date     3020 non-null   datetime64[ns]
#  3   Ship Date      3020 non-null   datetime64[ns]
#  4   Ship Mode      3020 non-null   object
#  5   Customer ID    3020 non-null   object
#  6   Customer Name  3020 non-null   object
#  7   Segment        3020 non-null   object
#  8   Country        3020 non-null   object
#  9   City           3020 non-null   object
#  10  State          3020 non-null   object
#  11  Postal Code    3020 non-null   int64
#  12  Region         3020 non-null   object
#  13  Product ID     3020 non-null   object
#  14  Category       3020 non-null   object
#  15  Sub-Category   3020 non-null   object
#  16  Product Name   3020 non-null   object
#  17  Sales          3020 non-null   float64
#  18  Quantity       3020 non-null   int64
#  19  Discount       3020 non-null   float64
#  20  Profit         3020 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 519.1+ KB

# %%
for i in corporate_data.columns:
  print(i,':','\n',corporate_data[i].unique())
# Out:
# Row ID :
#  [   3   22   23 ... 9967 9988 9989]
# Order ID :
#  ['CA-2016-138688' 'CA-2016-137330' 'CA-2016-117590' ... 'CA-2015-141593'
#  'CA-2016-146374' 'CA-2017-163629']
# Order Date :
#  <DatetimeArray>
# ['2016-06-12 00:00:00', '2016-12-09 00:00:00', '2016-12-08 00:00:00',
#  '2017-09-10 00:00:00', '2016-07-17 00:00:00', '2017-09-19 00:00:00',
#  '2016-03-11 00:00:00', '2016-12-11 00:00:00', '2014-12-05 00:00:00',
#  '2017-12-09 00:00:00',
#  ...
#  '2014-06-10 00:00:00', '2014-08-20 00:00:00', '2017-03-16 00:00:00',
#  '2014-02-14 00:00:00', '2015-06-08 00:00:00', '2016-05-02 00:00:00',
#  '2014-04-03 00:00:00', '2015-09-13 00:00:00', '2016-06-03 00:00:00',
#  '2014-03-02 00:00:00']
# Length: 830, dtype: datetime64[ns]
# Ship Date :
#  <DatetimeArray>
# ['2016-06-16 00:00:00', '2016-12-13 00:00:00', '2016-12-10 00:00:00',
#  '2017-09-15 00:00:00', '2016-07-22 00:00:00', '2017-09-23 00:00:00',
#  '2016-03-13 00:00:00', '2016-12-17 00:00:00', '2014-12-10 00:00:00',
#  '2017-12-11 00:00:00',
#  ...
#  '2017-03-21 00:00:00', '2015-11-12 00:00:00', '2014-02-18 00:00:00',
#  '2015-01-17 00:00:00', '2017-06-26 00:00:00', '2014-04-18 00:00:00',
#  '2015-03-28 00:00:00', '2014-11-03 00:00:00', '2016-07-28 00:00:00',
#  '2014-03-06 00:00:00']
# Length: 880, dtype: datetime64[ns]
# Ship Mode :
#  ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# Customer ID :
#  ['DV-13045' 'KB-16585' 'GH-14485' 'LC-16930' 'RA-19885' 'ES-14080'
#  'ON-18715' 'JM-15265' 'BS-11590' 'KB-16600' 'SC-20770' 'JC-16105'
#  'JS-15685' 'ER-13855' 'CV-12805' 'GG-14650' 'DW-13585' 'JD-15895'
#  'SH-19975' 'JE-16165' 'SP-20650' 'JB-15400' 'DK-13150' 'AM-10360'
#  'MZ-17515' 'FH-14365' 'HK-14890' 'MS-17980' 'VW-21775' 'DS-13180'
#  'EA-14035' 'DB-13120' 'DR-12880' 'Dl-13600' 'SB-20290' 'CB-12535'
#  'CA-12310' 'KH-16690' 'BB-10990' 'AG-10495' 'AH-10195' 'KL-16555'
#  'AS-10225' 'BP-11185' 'TS-21205' 'AG-10525' 'SP-20860' 'FA-14230'
#  'GK-14620' 'DJ-13510' 'AC-10420' 'VB-21745' 'MK-17905' 'MM-18280'
#  'AR-10405' 'AS-10285' 'LA-16780' 'DK-13225' 'BP-11095' 'SS-20140'
#  'KC-16675' 'MP-17965' 'KH-16630' 'BB-11545' 'EB-13705' 'MH-17785'
#  'JG-15805' 'MY-17380' 'MC-17605' 'KB-16240' 'EB-13840' 'NB-18655'
#  'GD-14590' 'NG-18355' 'SF-20965' 'DJ-13420' 'JD-16150' 'AR-10825'
#  'SP-20545' 'TH-21235' 'GT-14635' 'BN-11470' 'RS-19765' 'SC-20695'
#  'YC-21895' 'CP-12340' 'BF-11020' 'CS-12250' 'AJ-10795' 'BV-11245'
#  'HW-14935' 'MC-18130' 'BW-11110' 'BM-11650' 'EM-14095' 'CK-12760'
#  'DP-13105' 'AJ-10780' 'LS-16945' 'GP-14740' 'JS-15595' 'PC-18745'
#  'GB-14530' 'JR-16210' 'RW-19630' 'AH-10075' 'RP-19270' 'KC-16255'
#  'LW-16990' 'MW-18235' 'KM-16225' 'NS-18640' 'DG-13300' 'TS-21160'
#  'BT-11395' 'CY-12745' 'DL-13495' 'FH-14275' 'HR-14830' 'SW-20755'
#  'SP-20620' 'BG-11695' 'SM-20950' 'TB-21355' 'EB-13975' 'QJ-19255'
#  'HG-14965' 'LW-16825' 'GZ-14545' 'CP-12085' 'AS-10045' 'HM-14860'
#  'AB-10600' 'YS-21880' 'SV-20815' 'RW-19540' 'DK-12835' 'PW-19030'
#  'SC-20440' 'MC-17425' 'NH-18610' 'KD-16495' 'KN-16390' 'TS-21370'
#  'JW-15220' 'JM-15655' 'EB-13750' 'VG-21805' 'MY-18295' 'ML-17395'
#  'BS-11380' 'HH-15010' 'RB-19645' 'FM-14215' 'JE-15610' 'RP-19855'
#  'TB-21175' 'PB-19210' 'ND-18460' 'BF-10975' 'KH-16330' 'NC-18625'
#  'ME-18010' 'MD-17860' 'EH-13765' 'SC-20230' 'AC-10615' 'MC-17590'
#  'CC-12610' 'TC-20980' 'RF-19345' 'DB-13555' 'MH-17620' 'PJ-18835'
#  'RS-19420' 'EM-13825' 'BM-11575' 'SC-20260' 'EM-13810' 'ML-18040'
#  'GM-14695' 'LS-17200' 'LO-17170' 'KD-16615' 'NB-18580' 'KN-16450'
#  'BO-11350' 'AG-10300' 'MC-17635' 'TT-21265' 'RR-19525' 'CA-11965'
#  'DM-13345' 'BF-11275' 'AY-10555' 'DM-12955' 'JG-15310' 'JP-15460'
#  'CS-11845' 'AH-10030' 'DW-13195' 'CM-11815' 'CS-12490' 'DH-13075'
#  'JO-15145' 'AH-10690' 'FC-14335' 'NC-18535' 'DB-12970' 'MF-17665'
#  'KE-16420' 'CS-12175' 'TP-21565' 'SG-20890' 'BS-11365' 'SH-20635'
#  'GR-14560' 'TS-21430' 'MF-18250' 'AR-10345' 'KS-16300' 'LR-17035'
#  'JK-15325' 'DM-13525' 'TH-21115' 'MG-18205' 'BP-11050' 'AO-10810'
#  'MH-17440' 'LD-16855' 'VP-21760' 'TC-21145' 'CM-12715' 'FW-14395'
#  'HE-14800' 'CJ-11875']
# Customer Name :
#  ['Darrin Van Huff' 'Ken Black' 'Gene Hale' 'Linda Cazamias' 'Ruben Ausman'
#  'Erin Smith' 'Odella Nelson' 'Janet Molinari' 'Brendan Sweed'
#  'Ken Brennan' 'Stewart Carmichael' 'Julie Creighton' 'Jim Sink'
#  'Elpida Rittenbach' 'Cynthia Voltz' 'Greg Guthrie' 'Dorothy Wardle'
#  'Jonathan Doherty' 'Sally Hughsby' 'Justin Ellison' 'Stephanie Phelps'
#  'Jennifer Braxton' 'David Kendrick' 'Alice McCarthy' 'Mary Zewe'
#  'Fred Hopkins' 'Heather Kirkland' 'Michael Stewart' 'Victoria Wilson'
#  'David Smith' 'Erin Ashbrook' 'David Bremer' 'Dan Reichenbach'
#  'Dorris liebe' 'Sean Braxton' 'Claudia Bergmann' 'Christine Abelman'
#  'Kristen Hastings' 'Barry Blumstein' 'Andrew Gjertsen' 'Alan Haines'
#  'Kelly Lampkin' 'Alan Schoenberger' 'Ben Peterman' 'Thomas Seio'
#  'Andy Gerbode' 'Sung Pak' 'Frank Atkinson' 'Grace Kelly' 'Don Jones'
#  'Alyssa Crouse' 'Victoria Brennan' 'Michael Kennedy' 'Muhammed MacIntyre'
#  'Allen Rosenblatt' 'Alejandro Savely' 'Laura Armstrong' 'Dean Katz'
#  'Bart Pistole' 'Saphhira Shifley' 'Kimberly Carter' 'Michael Paige'
#  'Ken Heidel' 'Brenda Bowman' 'Ed Braxton' 'Maya Herman' 'John Grady'
#  'Maribeth Yedwab' 'Matt Connell' 'Karen Bern' 'Ellis Ballard' 'Nona Balk'
#  'Giulietta Dortch' 'Nat Gilpin' 'Sylvia Foulston' 'Denny Joy'
#  'Justin Deggeller' 'Anthony Rawles' 'Sibella Parks' 'Tiffany House'
#  'Grant Thornton' 'Brad Norvell' 'Roland Schwarz' 'Steve Chapman'
#  'Yoseph Carroll' 'Christine Phan' 'Barry Französisch' 'Chris Selesnick'
#  'Anthony Johnson' 'Benjamin Venier' 'Helen Wasserman' 'Mike Caudle'
#  'Bart Watters' 'Brian Moss' 'Eudokia Martin' 'Cyma Kinney' 'Dave Poirier'
#  'Anthony Jacobs' 'Linda Southworth' 'Guy Phonely' 'Jill Stevenson'
#  'Pamela Coakley' 'George Bell' 'Justin Ritter' 'Rob Williams' 'Adam Hart'
#  'Rachel Payne' 'Karen Carlisle' 'Lindsay Williams' 'Mitch Willingham'
#  'Kalyca Meade' 'Noel Staavos' 'Deirdre Greer' 'Theresa Swint'
#  'Bill Tyler' 'Craig Yedwab' 'Dionis Lloyd' 'Frank Hawley' 'Harold Ryan'
#  'Steven Ward' 'Stefania Perrino' 'Brooke Gillingham' 'Suzanne McNair'
#  'Todd Boyes' 'Erica Bern' 'Quincy Jones' 'Henry Goldwyn' 'Laurel Workman'
#  'George Zrebassa' 'Cathy Prescott' 'Aaron Smayling' 'Harry Marie'
#  'Ann Blume' 'Yana Sorensen' 'Stuart Van' 'Rick Wilson' 'Damala Kotsonis'
#  'Pauline Webber' 'Shaun Chance' 'Mark Cousins' 'Nicole Hansen'
#  'Keith Dawkins' 'Katherine Nockton' 'Todd Sumrall' 'Jane Waco'
#  'Jim Mitchum' 'Edward Becker' 'Vivek Grady' 'Muhammed Yedwab'
#  'Marina Lichtenstein' 'Bill Stewart' 'Hilary Holden' 'Robert Barroso'
#  'Filia McAdams' 'Jim Epp' 'Roy Phan' 'Thomas Boland' 'Phillip Breyer'
#  'Neil Ducich' 'Barbara Fisher' 'Katharine Harms' 'Noah Childs'
#  'Michelle Ellison' 'Michael Dominguez' 'Edward Hooks' 'Scot Coram'
#  'Ann Chong' 'Matt Collister' 'Corey Catlett' 'Tamara Chand'
#  'Randy Ferguson' 'Dorothy Badders' 'Matt Hagelstein' 'Patrick Jones'
#  'Ricardo Sperren' 'Elizabeth Moffitt' 'Brendan Murry' 'Scott Cohen'
#  'Eleni McCrary' 'Michelle Lonsdale' 'Greg Maxwell' 'Luke Schmidt'
#  'Lori Olson' 'Ken Dana' 'Nicole Brennan' 'Kean Nguyen' 'Bill Overfelt'
#  'Aleksandra Gannaway' 'Matthew Clasen' 'Tim Taslimi' 'Rick Reed'
#  'Carol Adams' 'Denise Monton' 'Beth Fritzler' 'Andy Yotov' 'Dario Medina'
#  'Jason Gross' 'Jennifer Patt' 'Cari Sayre' 'Aaron Hawkins' 'David Wiener'
#  'Candace McMahon' 'Cindy Schnelling' 'Dave Hallsten' "Jack O'Briant"
#  'Anna Häberlin' 'Fred Chung' 'Nick Crebassa' 'Darren Budd'
#  'Maureen Fritzler' 'Katrina Edelman' 'Charles Sheldon' 'Tracy Poddar'
#  'Susan Gilcrest' 'Bill Shonely' 'Stefanie Holloman' 'Georgia Rosenberg'
#  'Tom Stivers' 'Monica Federle' 'Alex Russell' 'Karen Seio' 'Lisa Ryan'
#  'Jason Klamczynski' 'Don Miller' 'Thea Hudgings' 'Mitch Gastineau'
#  'Barry Pond' "Anthony O'Donnell" 'Mark Haberlin' 'Lela Donovan'
#  'Victoria Pisteka' 'Theresa Coyne' 'Craig Molinari' 'Fred Wasserman'
#  'Harold Engle' 'Carl Jackson']
# Segment :
#  ['Corporate']
# Country :
#  ['United States']
# City :
#  ['Los Angeles' 'Fremont' 'Richardson' 'Naperville' 'Melbourne' 'Eagan'
#  'New York City' 'Gilbert' 'Houston' 'Decatur' 'Durham' 'Saint Paul'
#  'Bristol' 'Columbus' 'Philadelphia' 'San Francisco' 'Franklin' 'San Jose'
#  'Chicago' 'Grand Prairie' 'Redlands' 'Dallas' 'Medina' 'Detroit'
#  'Charlotte' 'Santa Clara' 'Pasadena' 'Chapel Hill' 'Cincinnati'
#  'Inglewood' 'Tamarac' 'Colorado Springs' 'Belleville' 'Taylor' 'Arvada'
#  'Hackensack' 'Saint Petersburg' 'Long Beach' 'Hesperia' 'Murfreesboro'
#  'Manchester' 'Quincy' 'Peoria' 'Warwick' 'Wilmington' 'Seattle'
#  'Richmond' 'Lawrence' 'Canton' 'San Antonio' 'Akron' 'Norman' 'Amarillo'
#  'Lindenhurst' 'Parker' 'Tucson' 'Anaheim' 'Dearborn' 'Warner Robins'
#  'Minneapolis' 'Sierra Vista' 'Vancouver' 'Burlington' 'Cleveland' 'Cary'
#  'Mount Vernon' 'Hialeah' 'San Diego' 'Jacksonville' 'Green Bay' 'Atlanta'
#  'Bossier City' 'Des Moines' 'Columbia' 'Rochester' 'Monroe' 'Milwaukee'
#  'Tampa' 'Fort Worth' 'Linden' 'Salinas' 'Springfield' 'Lancaster'
#  'Auburn' 'Farmington' 'Riverside' 'Torrance' 'Virginia Beach' 'Toledo'
#  'Oakland' 'Antioch' 'La Porte' 'Cuyahoga Falls' 'Reno' 'Coral Springs'
#  'Denver' 'Greenville' 'Louisville' 'Macon' 'Fairfield' 'Deltona'
#  'Norwich' 'Arlington' 'Aurora' 'Mesa' 'Mobile' 'New Bedford' 'Irving'
#  'Pomona' 'Newark' 'Miami' 'Bridgeton' 'Watertown' 'Bellevue' 'Grapevine'
#  'Dover' 'Skokie' 'North Las Vegas' 'Dublin' 'Fayetteville' 'Baltimore'
#  'Kenosha' 'Tulsa' 'Austin' 'Roswell' 'Bowling Green' 'Henderson'
#  'Huntington Beach' 'Indianapolis' 'Apopka' 'Reading' 'Carrollton'
#  'Montgomery' 'Brentwood' 'Chesapeake' 'Leominster' 'Lakewood'
#  'Perth Amboy' 'Rancho Cucamonga' 'Mesquite' 'Sunnyvale' 'York'
#  'San Angelo' 'Lincoln Park' 'Bangor' 'Middletown' 'Sioux Falls'
#  'Florence' 'Huntsville' 'Albuquerque' 'Sparks' 'Coachella' 'Westfield'
#  'Little Rock' 'La Quinta' 'Scottsdale' 'Haltom City' 'Summerville'
#  'Carlsbad' 'Saint Louis' 'Provo' 'Lowell' 'Hoover' 'Pompano Beach' 'Troy'
#  'Corpus Christi' 'Omaha' 'Redondo Beach' 'Woodstock' 'Palm Coast'
#  'Highland Park' 'Oceanside' 'Billings' 'Gresham' 'Providence' 'Lakeland'
#  'Maple Grove' 'Tallahassee' 'Woodland' 'Missouri City' 'Fresno'
#  'Pearland' 'Tempe' 'Grand Rapids' 'Visalia' 'Overland Park' 'Alexandria'
#  'Laredo' 'Gulfport' 'Round Rock' 'Yucaipa' 'Conroe' 'Tinley Park'
#  'Revere' 'Saint Cloud' 'Sacramento' 'Lafayette' 'Jackson' 'Smyrna'
#  'Plantation' 'Glendale' 'Phoenix' 'Clinton' 'Odessa' 'West Allis'
#  'Altoona' 'Greensboro' 'Knoxville' 'Baytown' 'Asheville'
#  'Port Saint Lucie' 'Bedford' 'Lorain' 'Tigard' 'Deer Park' 'Mcallen'
#  'Iowa City' 'Boise' 'Medford' 'Port Arthur' 'Redmond' 'Plainfield' 'Kent'
#  'Sandy Springs' 'Bakersfield' 'Marion' 'El Paso' 'Hattiesburg' 'Freeport'
#  'Spokane' 'Salem' 'Oak Park' 'Morristown' 'Marietta' 'Concord'
#  'Gaithersburg' 'Lehi' 'Nashville' 'Memphis' 'Raleigh' 'Vineland'
#  'Loveland' 'Woonsocket' 'Oklahoma City' 'Helena' 'Pueblo' 'Texarkana'
#  'Bethlehem' 'Roseville' 'Woodbury' 'Rockford' 'Cedar Hill' 'La Crosse'
#  'Apple Valley' 'Ann Arbor' 'Milford' 'Chattanooga' 'Meriden' 'Cranston'
#  'Owensboro' 'Bellingham' 'Southaven' 'Caldwell' 'Nashua' 'Redwood City'
#  'Plano' 'Palatine' 'Beverly' 'Eugene' 'Laguna Niguel' 'Chandler' 'Draper'
#  'Orlando' 'Buffalo' 'Edmonds' 'Fort Lauderdale' 'Stockton' 'Everett'
#  'Montebello' 'Thousand Oaks' 'Trenton' 'North Charleston' 'Las Vegas'
#  'Pleasant Grove' 'Chester' 'Athens' 'Hollywood' 'Yuma' 'Hillsboro'
#  'Garden City' 'Bloomington' 'Camarillo' 'Oxnard' 'Covington'
#  'Brownsville' 'Atlantic City' 'Newport News' 'Suffolk' 'Orem' 'Waterbury'
#  'Rome' 'Portland' 'Chico' 'Miramar' 'Modesto' 'East Point' 'Rapid City'
#  'Santa Barbara' 'El Cajon' 'Orange' 'Noblesville' 'Longmont' 'Hempstead'
#  'San Marcos' 'Escondido' 'Elyria' 'Twin Falls' 'Utica' 'Saint Charles'
#  'Meridian' 'Moreno Valley' 'Jamestown' 'Coral Gables' 'Santa Ana'
#  'Laurel' 'Wilson' 'Delray Beach' 'Waco' 'Eau Claire' 'Coppell' 'Paterson'
#  'Broken Arrow' 'Beaumont' 'Broomfield' 'Mansfield' 'Lubbock' 'Hampton'
#  'Lodi' 'Mason' 'Bryan']
# State :
#  ['California' 'Nebraska' 'Texas' 'Illinois' 'Florida' 'Minnesota'
#  'New York' 'Arizona' 'Alabama' 'North Carolina' 'Tennessee' 'Ohio'
#  'Pennsylvania' 'Wisconsin' 'Michigan' 'Colorado' 'New Jersey' 'Georgia'
#  'Connecticut' 'Massachusetts' 'Rhode Island' 'Washington' 'Kentucky'
#  'Oklahoma' 'Louisiana' 'Iowa' 'South Carolina' 'Virginia' 'New Mexico'
#  'Indiana' 'Nevada' 'Delaware' 'Maryland' 'Oregon' 'Missouri'
#  'New Hampshire' 'Vermont' 'Maine' 'South Dakota' 'Arkansas' 'Utah'
#  'Montana' 'Kansas' 'Mississippi' 'Idaho']
# Postal Code :
#  [90036 68025 75080 60540 90049 32935 55122 10024 85234 77041 35601 27707
#  55106 10035 37620 43229 19140 94122 53132 95123 60623 62521 75051 92374
#  19120 37064 75220 44256 48227 28205 95051 77506 77036 27514 45231 94110
#  90301 33319 80906  7109 48180 80004  7601 33710 19143 90805 92345 37130
#  31907  6040 62301  2038 94109 61604  2886 28403 98105 40475 90045  1841
#  48187 78207 77070 44312 73071 79109 11757 90008 80134 48234 85705 60653
#  92804 75217 10011 48126 31088 55407 85635 98661 75081 27217 44105 98103
#  27511 10550 48205 33012 92105 32216 10009 54302 30318 71111 50315 29203
#  14609 71203 53209 33614 76106  7036 93905 22153 17602 13021 45503 87401
#  92503 90503 47201 23464 60610 19134 92037 43615 94601 28110 94509 46350
#  44221 89502 90004 33065 80219 27834 80027 31204 94533 90032 32725  6360
#  28540 22204 60505 85204 80013 36608  2740 75061 98115 91767 19711 33142
#   8302 13601 98006 76051 19901 60076 89031 43017 28314 21215 53142 74133
#  78745 30076 42104  6010 43055 89015 92646 97477 46203 32712 19601 76017
#  75007 36116 94513 23320 65203  1453 44107 77095  8861 91730 75150 94086
#   3820 11561 17403 76903 48146  5408  4401 33180  6457 57103 42420 45014
#  29501 77340 87105 89431 92236  7090 72209 92253 85254 76117 29483 88220
#  63116 84604  1852 35244 33068 45373 78415 68104 90278 60098 32137 60035
#  92054 59102 97030 91104  2908 33801 11572 55369 32303 21044 95695 77489
#  93727 77581  8701 85281 49505 93277 66212 22304 78041 39503 78664 92399
#  77301 60477  2151 56301 95823 47905 49201 37167 33317 85301 85023 20735
#  79762 53214 16602 27405 65807 37918 77520 28806 38401 34952 76021 44052
#  97224 77536 78501 52240 83704 47374 97504  6824 38301 77642 97756  7060
#  44240 92024 30328 93309 43302 79907 39401 19805 23223 61032 99207 97301
#  60302  7960 30062  3301 20877 84043 37211 38109 27604  8360 80538  2895
#  70506 73120 59601 85345 81001 71854 18018 72701 55901 55113 55125 48237
#  43130 61107 35810 75104 39212 54601 92307 48104  6460 37421  6450  2920
#  42301 98226 38671 83605  3060 33178 94061 75023 60067  1915 97405 92677
#  85224 84020 32839 14215 95661 98026 33311 95207 98208 90640 91360 48183
#  29406 89115 40214 84062 94521 19013 12180 30605 33021 48066 85364 97123
#  67846 61701 93010 93030 98042 78521  8401 23602 23434 84057  6708 13440
#  97206 95928 33023 95351 30344 57701 93101 92020  7050 46060 80501 41042
#  11550 78666 92025 44035 83301 13501 63301 83642 92553 14701 33134 92704
#  20707 27893 52302 33445 76706 54703 75019  7501 74012 77705 80020 76063
#  43402 79424 23666 95240 45040 77803]
# Region :
#  ['West' 'Central' 'South' 'East']
# Product ID :
#  ['OFF-LA-10000240' 'OFF-AR-10000246' 'OFF-AP-10001492' ...
#  'OFF-AR-10000462' 'TEC-AC-10001539' 'TEC-PH-10004006']
# Category :
#  ['Office Supplies' 'Technology' 'Furniture']
# Sub-Category :
#  ['Labels' 'Art' 'Appliances' 'Phones' 'Furnishings' 'Storage'
#  'Accessories' 'Binders' 'Fasteners' 'Envelopes' 'Paper' 'Chairs'
#  'Bookcases' 'Machines' 'Tables' 'Supplies' 'Copiers']
# Product Name :
#  ['Self-Adhesive Address Labels for Typewriters by Universal' 'Newell 318'
#  "Acco Six-Outlet Power Strip, 4' Cord Length" ...
#  'Sanford Pocket Accent Highlighters'
#  'Logitech G430 Surround Sound Gaming Headset with Dolby 7.1 Technology'
#  'Panasonic KX - TS880B Telephone']
# Sales :
#  [ 14.62  19.46  60.34 ... 109.69  79.99 206.1 ]
# Quantity :
#  [ 2  7  5  4  8  3  1  6  9 11 10 13 12 14]
# Discount :
#  [0.   0.2  0.6  0.8  0.7  0.4  0.5  0.3  0.1  0.32 0.45 0.15]
# Profit :
#  [ 6.8714  5.0596 15.6884 ... 51.5543 28.7964 55.647 ]

# %%
for i in corporate_data.columns:
  print(i,':','\n',corporate_data[i].isnull().sum())
# Out:
# Row ID :
#  0
# Order ID :
#  0
# Order Date :
#  0
# Ship Date :
#  0
# Ship Mode :
#  0
# Customer ID :
#  0
# Customer Name :
#  0
# Segment :
#  0
# Country :
#  0
# City :
#  0
# State :
#  0
# Postal Code :
#  0
# Region :
#  0
# Product ID :
#  0
# Category :
#  0
# Sub-Category :
#  0
# Product Name :
#  0
# Sales :
#  0
# Quantity :
#  0
# Discount :
#  0
# Profit :
#  0

# %%
corporate_data.describe(include="all")
# Out:
#              Row ID        Order ID                     Order Date  \
# count   3020.000000            3020                           3020
# unique          NaN            1514                            NaN
# top             NaN  CA-2017-157987                            NaN
# freq            NaN              12                            NaN
# mean    5134.017881             NaN  2016-04-27 17:31:52.052980224
# min        3.000000             NaN            2014-01-06 00:00:00
# 25%     2584.000000             NaN            2015-05-03 12:00:00
# 50%     5340.500000             NaN            2016-07-02 00:00:00
# 75%     7646.500000             NaN            2017-05-13 00:00:00
# max     9989.000000             NaN            2017-12-30 00:00:00
# std     2894.431389             NaN                            NaN
#
#                             Ship Date       Ship Mode Customer ID  \
# count                            3020            3020        3020
# unique                            NaN               4         236
# top                               NaN  Standard Class    JD-15895
# freq                              NaN            1812          32
# mean    2016-05-01 17:42:50.066225152             NaN         NaN
# min               2014-01-07 00:00:00             NaN         NaN
# 25%               2015-05-07 00:00:00             NaN         NaN
# 50%               2016-07-03 00:00:00             NaN         NaN
# 75%               2017-05-17 00:00:00             NaN         NaN
# max               2018-01-05 00:00:00             NaN         NaN
# std                               NaN             NaN         NaN
#
#            Customer Name    Segment        Country           City  ...  \
# count               3020       3020           3020           3020  ...
# unique               236          1              1            340  ...
# top     Jonathan Doherty  Corporate  United States  New York City  ...
# freq                  32       3020           3020            266  ...
# mean                 NaN        NaN            NaN            NaN  ...
# min                  NaN        NaN            NaN            NaN  ...
# 25%                  NaN        NaN            NaN            NaN  ...
# 50%                  NaN        NaN            NaN            NaN  ...
# 75%                  NaN        NaN            NaN            NaN  ...
# max                  NaN        NaN            NaN            NaN  ...
# std                  NaN        NaN            NaN            NaN  ...
#
#          Postal Code  Region       Product ID         Category Sub-Category  \
# count    3020.000000    3020             3020             3020         3020
# unique           NaN       4             1456                3           17
# top              NaN    West  FUR-CH-10002880  Office Supplies      Binders
# freq             NaN     960                8             1820          473
# mean    54482.228477     NaN              NaN              NaN          NaN
# min      1453.000000     NaN              NaN              NaN          NaN
# 25%     22153.000000     NaN              NaN              NaN          NaN
# 50%     53209.000000     NaN              NaN              NaN          NaN
# 75%     90004.000000     NaN              NaN              NaN          NaN
# max     99207.000000     NaN              NaN              NaN          NaN
# std     32313.056957     NaN              NaN              NaN          NaN
#
#        Product Name         Sales     Quantity     Discount       Profit
# count          3020   3020.000000  3020.000000  3020.000000  3020.000000
# unique         1444           NaN          NaN          NaN          NaN
# top         Staples           NaN          NaN          NaN          NaN
# freq             18           NaN          NaN          NaN          NaN
# mean            NaN    233.823300     3.843709     0.158228    30.456667
# min             NaN      0.556000     1.000000     0.000000 -3839.990400
# 25%             NaN     17.469000     2.000000     0.000000     1.928400
# 50%             NaN     56.540000     3.000000     0.200000     8.694000
# 75%             NaN    212.895000     5.000000     0.200000    29.843500
# max             NaN  17499.950000    14.000000     0.800000  8399.976000
# std             NaN    599.410408     2.238676     0.206548   231.986266
#
# [11 rows x 21 columns]

# %%
corporate_data['Category'].value_counts()
# Out:
# Category
# Office Supplies    1820
# Furniture           646
# Technology          554
# Name: count, dtype: int64

# %%
plt.xlabel("(Category)")
plt.ylabel("(Quantities sold)")
corporate_data['Category'].value_counts().plot(kind='bar')
plt.title("Sales by the Corporates")
# Out:
# Text(0.5, 1.0, 'Sales by the Corporates')

# %%
corporate_data['Region'].value_counts().plot(kind="pie",autopct='%1.0f%%')
plt.title("Region-Wise Sales by the Corporates")
plt.show()
